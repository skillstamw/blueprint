# %%
#
from rudimentary_functions import print_hello_blue_print

print_hello_blue_print()

#so it is possible to use a function
# Out:
# hello blueprint

# %%
from scrape.get_scrape import get_scrape

url="https://pubmed.ncbi.nlm.nih.gov/27471967/"#"https://arxiv.org/abs/2604.07248"

result=get_scrape(url=url)

# %%
from scrape.scrape_and_count import scrape_and_count
words = [
        "algorithm", "artificial", "intelligence", "uncertain", "prediction", 
        "loss", "model", "definition", "parameter", "solution", "derived", "application",
        "declare", "code", "data", "result", "variability", "variance", 
        "variation", "power", "significance", "hypothesis", "theory", "available"]

result=scrape_and_count(url=url,words=["Wallden"])
print(result)
# Out:
# (0, 13072)

# %%
from scrape.validate_url import validate_url

validate_url("https://www.allabolag.se/foretag/skillsta-teknik-design-och-kvalitet-ab/v%C3%A4nge/f%C3%B6retagsutveckling/2KGEHEHI5YEHU")
# Out:
# True

# %%
from get_time_stamp import get_time_stamp
from uuid import UUID
from scrape.get_formatted_scrape_file_name import hello
hello()
from scrape.get_formatted_scrape_file_name import get_formatted_scrape_file_name
time_stamp=get_time_stamp()
formatted_scrape_file_name=get_formatted_scrape_file_name(scrape_id=UUID("3ca1cab7-a143-4928-98c4-035d53ffcc9e"),time_stamp=time_stamp)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 3
#       1 from get_time_stamp import get_time_stamp
#       2 from uuid import UUID
# ----> 3 from scrape.get_formatted_scrape_file_name import hello
#       4 hello()
#       5 from scrape.get_formatted_scrape_file_name import get_formatted_scrape_file_name
#       6 time_stamp=get_time_stamp()
#
# ImportError: cannot import name 'hello' from 'scrape.get_formatted_scrape_file_name' (c:\Users\MatsWallden\OneDrive - Quality by Skillsta\Documents\MEDUSA\blueprint\scrape\get_formatted_scrape_file_name.py)

# %%
from filter.extract_keyword_sentences

# %%
from filter.pre_process_scrape import hello

pre_process_scrape.hello()

result=get_scrape(url=url)

print(len(result))

pre_processed_scrape=pre_process_scrape(result)

print(len(pre_processed_scrape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 from filter.pre_process_scrape import hello
#       2
#       3
# ----> 4 pre_process_scrape.hello()
#       5
#       6 result=get_scrape(url=url)
#       7
#
# NameError: name 'pre_process_scrape' is not defined

# %%
#import hashlib

# def get_sha(text):
#     hash_object = hashlib.sha256(text.encode('utf-8'))
#     hash_hex = hash_object.hexdigest()
#     return hash_hex
from filter.get_sha import get_sha

print(get_sha("I CANT GET YOU OUT OF MY SYSTEM"))
# Out:
# cdb759f8aa6035962774d6d4fdeca87b3a74f2a0cb11b4bae77f865ec9f27b85

# %%
from scrape.get_formatted_scrape import get_formatted_scrape

get_formatted_scrape(text=result)
# Out:
# {'id': '5f801a9b-54f3-4a41-a12c-cf246bd2c12c',
#  'url': None,
# ...

# %%
# Can we scrape? 

from uuid import uuid4
from scrape.get_formatted_scrape import get_formatted_scrape
from scrape.validate_url import validate_url
from get_formatted_scrape_file_name import get_formatted_scrape_file_name
from scrape.write_formatted_scrape_sequence import write_formatted_scrape

from uuid import UUID



url="https://arxiv.org/html/2601.00044v2"

try:
    validate_url(url=url)

    scrape=get_scrape(url=url)

    time_stamp=get_time_stamp()

    scrape_id=uuid4()

    formatted_scrape=get_formatted_scrape(text=scrape,
                                          url=url,
                                          scrape_id=scrape_id)
    

    formatted_scrape_file_name=get_formatted_scrape_file_name(scrape_id=scrape_id,
                                                              time_stamp=time_stamp)
    
    write_formatted_scrape(file_name=formatted_scrape_file_name,
                                    formatted_scrape=formatted_scrape
                                    )
except AssertionError as ass_error:
    print(ass_error)
# Out:
# {'id': 'ab858f46-2c37-45dd-a232-16b8bcde789b', 'url': 'https://arxiv.org/html/2601.00044v2', 'body': '\n \n \n Born in the Dark: The Catastrophic Collapse of Fuzzy Dark Matter Solitons as the Origin of Little Red Dots \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n Report GitHub Issue \n × \n \n \n Title: \n \n Content selection saved. Describe the issue below: \n Description: \n \n \n \n Submit without GitHub \n Submit in GitHub \n \n \n \n \n \n \n \n Back to arXiv \n \n \n \n \n Why HTML? \n \n \n \n \n Report Issue \n \n \n \n \n \n \n Back to Abstract \n \n \n \n \n \n \n Download PDF \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n Abstract \n I  Introduction \n \n II  Analytic Framework \n \n II.1  Soliton Scaling and Parameter Constraints \n \n II.2  Derivation of the Opacity Crisis \n \n A conservative column estimate from the baryon mass budget. \n Relation to hydrostatic stratification. \n Cooling ve
# ...
